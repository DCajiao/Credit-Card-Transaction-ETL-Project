# %% [markdown]
# ### **API EDA process**:
#
# - Objective: This workbook presents the process of interaction with the API and the integration with the main data (Credit Card Transactions).
#
# So, we are looking to get population information from the API, full name of the State and country code and name. (This will not be a problem since the dataset represents the population of the United States).
#
# ---

# %% [markdown]
# #### **First Step**: Obtain the list of states present in our data

# %%
import requests
import pandas as pd
import sys
import os

# Add the 'src' folder to sys.path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

# %%
from connections.db import DB
db = DB()

# Fetch the data from the database as a dataframe
df = db.fetch_as_dataframe("SELECT * FROM raw_table;")
# Out:
# INFO:root:✔ Connected to database
# INFO:root:✔ Data loaded into DataFrame
# INFO:root:✔ Cursor closed
# INFO:root:✔ Connection closed

# %%
df['state'].unique()
# Out:
# array(['NC', 'ID', 'VA', 'PA', 'TN', 'IA', 'WV', 'FL', 'NJ', 'OK', 'IN',
#        'MA', 'TX', 'WI', 'MI', 'WY', 'HI', 'LA', 'DC', 'KY', 'NY', 'MS',
#        'KS', 'AL', 'WA', 'AR', 'MD', 'GA', 'ME', 'CA', 'NE', 'MN', 'OH',
#        'MO', 'SC', 'OR', 'IL', 'NH', 'CO', 'SD', 'MT', 'ND', 'CT', 'VT',
#        'AZ', 'UT', 'NM', 'NV', 'RI'], dtype=object)

# %% [markdown]
# #### **Second Step**: Connect to the API to obtain the population of each State and perform the merge.

# %%
API_URL = "https://api-world-population-etl-project.onrender.com/api/v1/data/usa/states"

response = requests.get(API_URL)
df_api = pd.DataFrame(response.json())
df_api
# Out:
#           Country Country_Code State_Abbreviation            State_Name  \
# 0   United States          USA                 AL               Alabama
# 1   United States          USA                 AK                Alaska
# 2   United States          USA                 AZ               Arizona
# 3   United States          USA                 AR              Arkansas
# 4   United States          USA                 CA            California
# 5   United States          USA                 CO              Colorado
# 6   United States          USA                 CT           Connecticut
# 7   United States          USA                 DE              Delaware
# 8   United States          USA                 DC  District of Columbia
# 9   United States          USA                 FL               Florida
# 10  United States          USA                 GA               Georgia
# 11  United States          USA                 HI                Hawaii
# 12  United States          USA                 ID                 Idaho
# 13  United States          USA                 IL              Illinois
# 14  United States          USA                 IN               Indiana
# 15  United States          USA                 IA                  Iowa
# 16  United States          USA                 KS                Kansas
# 17  United States          USA                 KY              Kentucky
# 18  United States          USA                 LA             Louisiana
# 19  United States          USA                 ME                 Maine
# 20  United States          USA                 MD              Maryland
# 21  United States          USA                 MA         Massachusetts
# 22  United States          USA                 MI              Michigan
# 23  United States          USA                 MN             Minnesota
# 24  United States          USA                 MS           Mississippi
# 25  United States          USA                 MO              Missouri
# 26  United States          USA                 MT               Montana
# 27  United States          USA                 NE              Nebraska
# 28  United States          USA                 NV                Nevada
# 29  United States          USA                 NH         New Hampshire
# 30  United States          USA                 NJ            New Jersey
# 31  United States          USA                 NM            New Mexico
# 32  United States          USA                 NY              New York
# 33  United States          USA                 NC        North Carolina
# 34  United States          USA                 ND          North Dakota
# 35  United States          USA                 OH                  Ohio
# 36  United States          USA                 OK              Oklahoma
# 37  United States          USA                 OR                Oregon
# 38  United States          USA                 PA          Pennsylvania
# 39  United States          USA                 RI          Rhode Island
# 40  United States          USA                 SC        South Carolina
# 41  United States          USA                 SD          South Dakota
# 42  United States          USA                 TN             Tennessee
# 43  United States          USA                 TX                 Texas
# 44  United States          USA                 UT                  Utah
# 45  United States          USA                 VT               Vermont
# 46  United States          USA                 VA              Virginia
# 47  United States          USA                 WA            Washington
# 48  United States          USA                 WV         West Virginia
# 49  United States          USA                 WI             Wisconsin
# 50  United States          USA                 WY               Wyoming
#
#     State_Population
# 0            5024294
# 1             733374
# 2            7157902
# 3            3011490
# 4           39538212
# 5            5773707
# 6            3605912
# 7             989946
# 8             689548
# 9           21538216
# 10          10713771
# 11           1455274
# 12           1839117
# 13          12813469
# 14           6785442
# 15           3190427
# 16           2937835
# 17           4506297
# 18           4657785
# 19           1363177
# 20           6177253
# 21           7032933
# 22          10077674
# 23           5706804
# 24           2961306
# 25           6154889
# 26           1084244
# 27           1961965
# 28           3104617
# 29           1377524
# 30           9289039
# 31           2117525
# 32          20202320
# 33          10439459
# 34            779079
# 35          11799331
# 36           3959411
# 37           4237279
# 38          13002788
# 39           1097371
# 40           5118422
# 41            886668
# 42           6910786
# 43          29145459
# 44           3271614
# 45            643077
# 46           8631373
# 47           7705267
# 48           1793713
# 49           5893713
# 50            576850

# %%
# Merge using the column “state”. 
df_api.columns = [col.lower() for col in df_api.columns.to_list()]
df = df.merge(df_api, left_on='state', right_on='state_abbreviation', how='left')

# %%
df.columns
# Out:
# Index(['id', 'trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat',
#        'long', 'job', 'dob', 'trans_num', 'is_fraud', 'merch_zipcode', 'age',
#        'country', 'country_code', 'state_abbreviation', 'state_name',
#        'state_population'],
#       dtype='object')

# %%
# Save the preprocessed data to a new CSV file.
df.to_csv('../data/credit_card_transactions_api_preprocessed.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# #### **Fourth Step**: Simplify the entire process into one or more functions and then run it in Airflow

# %%
import logging
import pandas as pd
import requests

logging.basicConfig(level=logging.INFO)

def api_connect():
    API_URL = "https://api-world-population-etl-project.onrender.com/api/v1/data/usa/states"
    response = requests.get(API_URL)
    
    if response is None or response.status_code != 200:
        logging.error(f'API connection failed. Status code: {response.status_code}')
        return None
    
    df_api = pd.DataFrame(response.json())
    
    return df_api

def merge_data(df, df_api):
    df_api.columns = [col.lower() for col in df_api.columns.to_list()]
    df = df.merge(df_api, left_on='state', right_on='state_abbreviation', how='left')
    return df

# Main function
def api_integration(df):
    try:
        df_api = api_connect()
        df = merge_data(df, df_api)
        df.to_csv('../data/credit_card_transactions_api_preprocessed.csv', index=False)
    except Exception as e:
        logging.error(f'API integration failed. Error: {str(e)}')
